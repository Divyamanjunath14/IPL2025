# %%
import pandas as pd

# Reading the CSV file
df1 = pd.read_csv(r"C:\Users\divya\Downloads\IPL2025\matches.csv")
df2 = pd.read_csv(r"C:\Users\divya\Downloads\IPL2025\deliveries.csv")

df1.head()
df2.head()
# Out:
#    21:50          date         stage                  venue batting_team  \
# 0      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 1      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 2      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 3      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 4      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
#
#   bowling_team  innings  over  striker     bowler  runs_of_bat  extras  wide  \
# 0          RCB        1   0.1  de Kock  Hazlewood            0       0     0
# 1          RCB        1   0.2  de Kock  Hazlewood            4       0     0
# 2          RCB        1   0.3  de Kock  Hazlewood            0       0     0
# 3          RCB        1   0.4  de Kock  Hazlewood            0       0     0
# 4          RCB        1   0.5  de Kock  Hazlewood            0       0     0
#
# ...

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt


sns.countplot(x='match_winner', data=df1, )
plt.show()

# %%
import pandas as pd
merged_df = pd.merge(df1, df2, on="venue")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: scatter plot of runs vs balls_faced, colored by team
sns.scatterplot(data=merged_df, x="team1", y="team2", hue="match_winner")

plt.title("Team vs winning team")

plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
import pandas as pd

# Reading the CSV file
df1 = pd.read_csv(r"C:\Users\divya\Downloads\IPL2025\matches.csv")
df2 = pd.read_csv(r"C:\Users\divya\Downloads\IPL2025\deliveries.csv")

df1.head()
df2.head()
# Out:
#    21:50          date         stage                  venue batting_team  \
# 0      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 1      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 2      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 3      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
# 4      1  Mar 22, 2025  League stage  Eden Gardens, Kolkata          KKR
#
#   bowling_team  innings  over  striker     bowler  runs_of_bat  extras  wide  \
# 0          RCB        1   0.1  de Kock  Hazlewood            0       0     0
# 1          RCB        1   0.2  de Kock  Hazlewood            4       0     0
# 2          RCB        1   0.3  de Kock  Hazlewood            0       0     0
# 3          RCB        1   0.4  de Kock  Hazlewood            0       0     0
# 4          RCB        1   0.5  de Kock  Hazlewood            0       0     0
#
# ...

# %%
# Ensure column names are clean
matches.columns = matches.columns.str.strip()
deliveries.columns = deliveries.columns.str.strip()

# Merge both DataFrames
merged_df = pd.merge(deliveries, matches, on="venue", how="inner")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Ensure column names are clean
# ----> 2 matches.columns = matches.columns.str.strip()
#       3 deliveries.columns = deliveries.columns.str.strip()
#       5 # Merge both DataFrames
#
# NameError: name 'matches' is not defined

# %%
pairplot_df = merged_df[["batting_team", "over", "second_ings_score","first_ings_score"]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(pairplot_df, hue="batting_team", diag_kind="kde", palette="tab10")
plt.suptitle("Team Run Patterns Across Matches", y=1.02)
plt.show()
# Out:
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
